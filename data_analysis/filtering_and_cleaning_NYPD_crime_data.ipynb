# %% [markdown]
# # Filtering and cleaning NYPD Complaint and Arrests data
#
# * The two files:
#     1. `NYPD_Complaint_Data_Historic.csv` - **https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i**
#     2. `NYPD_Arrests_Data__Historic_.csv` - **https://data.cityofnewyork.us/Public-Safety/NYPD-Arrests-Data-Historic-/8h9b-rp9u**
#
#
# * Contain all complaints/arrests recorded from 2006 through the end of the previous calender year (2019). These two datasets are too large to work with easily. So we want to apply a file filter to select the lines that relate to sexual assaults or sex crimes, as well as remove columns not necessary for analysis.

# %% [markdown]
# ### 1. Filtering the complaint data
#
# 1. Define a list of crime categories.
# 2. Read each line in the CSV file and look at the 9th field/column.
# 3. If it contains a string that is in the categories of interest, add current line to filter list.

# %%
SA_cats = ['RAPE', 'SEX CRIMES', 'FORCIBLE TOUCHING']

# %%
filtered_lines = []
for lnum, line in enumerate(open('../data/raw/NYPD_Complaint_Data_Historic.csv')):
    
    # add the first line of file into flitered_list (this is the column headers)
    if lnum==0:
        filtered_lines.append(line)
    
    # if the 9th field in the current line matches one of the string in SA_cats add to list
    fields = line.split(',')
    if fields[8] in SA_cats:
        filtered_lines.append(line)

# %% [markdown]
# * Now write out the filtered list as a CSV file

# %%
with open('../data/raw/NYPD_Complaint_Data_Historic_FILTERED_SAcrimes.csv', 'w') as out:
    for line in filtered_lines:
        out.write(line)

# %% [markdown]
# ### 2. Cleaning the complaint data
# 1. Look at the columns in data set
# 2. Filter for columns necessary for analysis
# 3. Create a new data frame with just those columns
# 2. Rename columns

# %%
import pandas as pd 
nyc_complaints_df = pd.read_csv('../data/raw/NYPD_Complaint_Data_Historic_FILTERED_SAcrimes.csv')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (18,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
nyc_complaints_df.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'ADDR_PCT_CD', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD',
#        'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'JURIS_DESC', 'JURISDICTION_CODE',
#        'PARKS_NM', 'HADEVELOPT', 'HOUSING_PSA', 'X_COORD_CD', 'Y_COORD_CD',
#        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT',
#        'Latitude', 'Longitude', 'Lat_Lon', 'PATROL_BORO', 'STATION_NAME',
#        'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX'],
#       dtype='object')

# %%
cols= ['BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
       'CMPLNT_TO_TM','ADDR_PCT_CD', 'RPT_DT', 'KY_CD', 'OFNS_DESC',
       'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD',
       'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC',
       'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX','VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX']
nyc_SA_complaints = nyc_complaints_df[cols]
cname_dict= {
    'BORO_NM': 'borough', 
    'CMPLNT_FR_DT': 'start_date', 
    'CMPLNT_FR_TM': 'start_time', 
    'CMPLNT_TO_DT': 'end_date',
    'CMPLNT_TO_TM': 'end_time',
    'ADDR_PCT_CD': 'precinct',
    'RPT_DT': 'report_date',
    'KY_CD': 'classif_code',
    'OFNS_DESC': 'offense_desc',
    'PD_DESC': 'pd_desc',
    'CRM_ATPT_CPTD_CD': 'crime_cmpltn',
    'LAW_CAT_CD': 'offense_lvl',
    'LOC_OF_OCCUR_DESC': 'location', 
    'PREM_TYP_DESC': 'premises_desc',
    'SUSP_AGE_GROUP': 'suspect_age',
    'SUSP_RACE': 'suspect_race',
    'SUSP_SEX': 'suspect_sex', 
    'VIC_AGE_GROUP': 'vic_age',
    'VIC_RACE': 'vic_race',
    'VIC_SEX': 'vic_sex'
}
nyc_SA_complaints= nyc_SA_complaints.rename(columns=cname_dict)
nyc_SA_complaints
# Out:
#           borough  start_date start_time    end_date  end_time  precinct  \
# 0        BROOKLYN  10/16/2007   02:00:00  12/31/2007  03:00:00      83.0
# 1        BROOKLYN  01/01/2006   00:01:00  01/01/2006  23:59:00      75.0
# 2          QUEENS  02/18/2013   05:00:00  02/18/2013  05:25:00     110.0
# 3        BROOKLYN  04/26/2015   12:00:00  04/26/2015  12:30:00      69.0
# 4        BROOKLYN  10/17/2012   01:00:00  10/17/2012  06:36:00      67.0
# ...           ...         ...        ...         ...       ...       ...
# 105768  MANHATTAN  02/18/2013   04:25:00         NaN       NaN      13.0
# 105769   BROOKLYN  10/20/2016   19:30:00  10/20/2016  19:35:00      76.0
# 105770  MANHATTAN  03/13/2015   16:10:00  03/15/2015  16:11:00      17.0
# 105771     QUEENS  10/10/2014   13:05:00         NaN       NaN     110.0
# 105772     QUEENS  06/25/2015   11:05:00  06/25/2015  11:06:00     115.0
#
#        report_date  classif_code offense_desc                     pd_desc  \
# 0       03/11/2016           116   SEX CRIMES                SEXUAL ABUSE
# 1       10/21/2012           116   SEX CRIMES    AGGRAVATED SEXUAL ASBUSE
# 2       02/18/2013           233   SEX CRIMES            SEXUAL ABUSE 3,2
# 3       04/27/2015           116   SEX CRIMES                SEXUAL ABUSE
# 4       10/17/2012           104         RAPE                      RAPE 1
# ...            ...           ...          ...                         ...
# 105768  02/18/2013           233   SEX CRIMES            SEXUAL ABUSE 3,2
# 105769  10/21/2016           233   SEX CRIMES            SEXUAL ABUSE 3,2
# 105770  03/16/2015           233   SEX CRIMES  CHILD, ENDANGERING WELFARE
# 105771  10/21/2014           233   SEX CRIMES            SEXUAL ABUSE 3,2
# 105772  06/25/2015           233   SEX CRIMES            SEXUAL ABUSE 3,2
#
#        crime_cmpltn  offense_lvl  location           premises_desc  \
# 0         COMPLETED       FELONY    INSIDE  RESIDENCE - APT. HOUSE
# 1         COMPLETED       FELONY    INSIDE         RESIDENCE-HOUSE
# 2         COMPLETED  MISDEMEANOR    INSIDE        RESTAURANT/DINER
# 3         COMPLETED       FELONY    INSIDE          GROCERY/BODEGA
# 4         COMPLETED       FELONY    INSIDE         RESIDENCE-HOUSE
# ...             ...          ...       ...                     ...
# 105768    COMPLETED  MISDEMEANOR  FRONT OF  RESIDENCE - APT. HOUSE
# 105769    COMPLETED  MISDEMEANOR       NaN                  STREET
# 105770    COMPLETED  MISDEMEANOR    INSIDE     COMMERCIAL BUILDING
# 105771    COMPLETED  MISDEMEANOR    INSIDE           PUBLIC SCHOOL
# 105772    COMPLETED  MISDEMEANOR  FRONT OF                  STREET
#
#        suspect_age    suspect_race suspect_sex vic_age  \
# 0            25-44  WHITE HISPANIC           M     <18
# 1              NaN           BLACK           M     <18
# 2              NaN             NaN         NaN   18-24
# 3              NaN             NaN         NaN     <18
# 4              NaN             NaN         NaN   25-44
# ...            ...             ...         ...     ...
# 105768         NaN             NaN         NaN   18-24
# 105769         <18           BLACK           M     <18
# 105770       25-44  WHITE HISPANIC           F   45-64
# 105771         <18  WHITE HISPANIC           M     <18
# 105772         NaN  WHITE HISPANIC           M   45-64
#
#                         vic_race vic_sex
# 0                 WHITE HISPANIC       F
# 1                          BLACK       F
# 2                 WHITE HISPANIC       M
# 3                          BLACK       F
# 4                          BLACK       F
# ...                          ...     ...
# 105768  ASIAN / PACIFIC ISLANDER       F
# 105769                     BLACK       F
# 105770            WHITE HISPANIC       F
# 105771            WHITE HISPANIC       F
# 105772            WHITE HISPANIC       F
#
# [105773 rows x 20 columns]

# %% [markdown]
# There is a typo in 2 rows, so I'm going to rename the elements.

# %%
nyc_SA_complaints.at[65823, 'start_date']= '10/11/2019'
nyc_SA_complaints.at[68821, 'start_date']= '10/11/2019'

# %% [markdown]
# #### Exporting nyc_SA_complaints DataFrame as a csv

# %%
nyc_SA_complaints.to_csv(r'../data/clean/NYPD_Complaint_Data_Historic_CLEAN_SA.csv')

# %% [markdown]
# ### 3. Filtering the arrest data
#
# 1. Define a list of crime categories.
# 2. Read each line in the CSV file and look at the 9th field/column.
# 3. If it contains a string that is in the categories of interest, add current line to filter list.

# %%
arrest_filtered_lines = []
for lnum, line in enumerate(open('../data/raw/NYPD_Arrests_Data__Historic_.csv')):
    
    # add the first line of file into flitered_list (this is the column headers)
    if lnum==0:
        arrest_filtered_lines.append(line)
    
    # if the 9th field in the current line matches one of the string in SA_cats add to list
    fields = line.split(',')
    if fields[5] in SA_cats:
        arrest_filtered_lines.append(line)

# %%
with open('../data/raw/NYPD_Arrests_Data__Historic_FILTERED_SAcrimes.csv', 'w') as out:
    for line in arrest_filtered_lines:
        out.write(line)

# %% [markdown]
# ### 4. Cleaning the arrests data
# 1. Look at the columns in data set
# 2. Filter for columns necessary for analysis
# 3. Create a new data frame with just those columns
# 2. Rename columns

# %%
nyc_arrests_df = pd.read_csv('../data/raw/NYPD_Arrests_Data__Historic_FILTERED_SAcrimes.csv')

# %%
nyc_arrests_df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD  \
# 0       144954157  07/31/2015    153
# 1       143915509  06/23/2015    180
# 2       144128610  06/30/2015    157
# 3       144454407  07/12/2015    168
# 4       144342696  07/08/2015    157
# ...           ...         ...    ...
# 22474   206870062  12/29/2019    157
# 22475   204904841  11/08/2019    164
# 22476   206255195  12/10/2019    177
# 22477   205789935  11/29/2019    177
# 22478   203871125  10/17/2019    153
#
#                                         PD_DESC  KY_CD   OFNS_DESC  \
# 0                                        RAPE 3    104        RAPE
# 1      COURSE OF SEXUAL CONDUCT AGAINST A CHILD    116  SEX CRIMES
# 2                                        RAPE 1    104        RAPE
# 3                                      SODOMY 1    116  SEX CRIMES
# 4                                        RAPE 1    104        RAPE
# ...                                         ...    ...         ...
# 22474                                    RAPE 1    104        RAPE
# 22475                                  SODOMY 3    116  SEX CRIMES
# 22476                              SEXUAL ABUSE    116  SEX CRIMES
# 22477                              SEXUAL ABUSE    116  SEX CRIMES
# 22478                                    RAPE 3    104        RAPE
#
#          LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0      PL 1302502          F           Q              112                  0
# 1      PL 130801B          F           M               25                  0
# 2      PL 1303501          F           K               90                  2
# 3      PL 1305001          F           K               81                  0
# 4      PL 1303501          F           M               25                  0
# ...           ...        ...         ...              ...                ...
# 22474  PL 1303501          F           Q              112                  0
# 22475  PL 1304001          F           K               70                  0
# 22476  PL 1306502          F           Q              112                  0
# 22477  PL 1306504          F           K               84                  0
# 22478  PL 1302501          F           B               47                  0
#
#       AGE_GROUP PERP_SEX                       PERP_RACE  X_COORD_CD  \
# 0         25-44        M                           BLACK   1025420.0
# 1         18-24        M                  WHITE HISPANIC   1000555.0
# 2         18-24        M                           BLACK    997843.0
# 3         45-64        M                           BLACK   1005218.0
# 4         25-44        M                           BLACK   1000555.0
# ...         ...      ...                             ...         ...
# 22474     18-24        M                           BLACK   1025420.0
# 22475       <18        M  AMERICAN INDIAN/ALASKAN NATIVE    991547.0
# 22476     45-64        M                  WHITE HISPANIC   1025420.0
# 22477     45-64        M                           BLACK    989013.0
# 22478     18-24        F                  WHITE HISPANIC   1026387.0
#
#        Y_COORD_CD   Latitude  Longitude  \
# 0        202485.0  40.722364 -73.851474
# 1        230994.0  40.800694 -73.941109
# 2        196573.0  40.706222 -73.950974
# 3        190528.0  40.689615 -73.924393
# 4        230994.0  40.800694 -73.941109
# ...           ...        ...        ...
# 22474    202485.0  40.722364 -73.851474
# 22475    168934.0  40.630367 -73.973713
# 22476    202485.0  40.722364 -73.851474
# 22477    192652.0  40.695469 -73.982825
# 22478    262634.0  40.887451 -73.847608
#
#                                              Lon_Lat
# 0       POINT (-73.85147389399998 40.72236368700005)
# 1      POINT (-73.94110928599997 40.800694331000045)
# 2       POINT (-73.95097435599996 40.70622201300005)
# 3      POINT (-73.92439311199998 40.689615497000034)
# 4      POINT (-73.94110928599997 40.800694331000045)
# ...                                              ...
# 22474   POINT (-73.85147389399998 40.72236368700005)
# 22475   POINT (-73.97371261299998 40.63036654500007)
# 22476   POINT (-73.85147389399998 40.72236368700005)
# 22477   POINT (-73.98282507899995 40.69546894100006)
# 22478   POINT (-73.84760778699996 40.88745131300004)
#
# [22479 rows x 19 columns]

# %%
nyc_arrests_df.columns
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'Lon_Lat'],
#       dtype='object')

# %%
cols2= ['ARREST_DATE','ARREST_BORO','ARREST_PRECINCT','KY_CD','OFNS_DESC','PD_DESC', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE']
nyc_SA_arrests = nyc_arrests_df[cols2]
cname_dict= {
    'ARREST_DATE': 'arrest_date',
    'ARREST_BORO': 'arrest_borough', 
    'ARREST_PRECINCT': 'arrest_precinct', 
    'KY_CD': 'classif_code',
    'OFNS_DESC': 'offense_desc',
    'PD_DESC': 'pd_desc',
    'AGE_GROUP': 'perp_age',
    'PERP_SEX': 'perp_sex',
    'PERP_RACE': 'perp_race', 
}
nyc_SA_arrests= nyc_SA_arrests.rename(columns=cname_dict)
nyc_SA_arrests
# Out:
#       arrest_date arrest_borough  arrest_precinct  classif_code offense_desc  \
# 0      07/31/2015              Q              112           104         RAPE
# 1      06/23/2015              M               25           116   SEX CRIMES
# 2      06/30/2015              K               90           104         RAPE
# 3      07/12/2015              K               81           116   SEX CRIMES
# 4      07/08/2015              M               25           104         RAPE
# ...           ...            ...              ...           ...          ...
# 22474  12/29/2019              Q              112           104         RAPE
# 22475  11/08/2019              K               70           116   SEX CRIMES
# 22476  12/10/2019              Q              112           116   SEX CRIMES
# 22477  11/29/2019              K               84           116   SEX CRIMES
# 22478  10/17/2019              B               47           104         RAPE
#
#                                         pd_desc perp_age perp_sex  \
# 0                                        RAPE 3    25-44        M
# 1      COURSE OF SEXUAL CONDUCT AGAINST A CHILD    18-24        M
# 2                                        RAPE 1    18-24        M
# 3                                      SODOMY 1    45-64        M
# 4                                        RAPE 1    25-44        M
# ...                                         ...      ...      ...
# 22474                                    RAPE 1    18-24        M
# 22475                                  SODOMY 3      <18        M
# 22476                              SEXUAL ABUSE    45-64        M
# 22477                              SEXUAL ABUSE    45-64        M
# 22478                                    RAPE 3    18-24        F
#
#                             perp_race
# 0                               BLACK
# 1                      WHITE HISPANIC
# 2                               BLACK
# 3                               BLACK
# 4                               BLACK
# ...                               ...
# 22474                           BLACK
# 22475  AMERICAN INDIAN/ALASKAN NATIVE
# 22476                  WHITE HISPANIC
# 22477                           BLACK
# 22478                  WHITE HISPANIC
#
# [22479 rows x 9 columns]

# %% [markdown]
# #### Exporting nyc_SA_arrests DataFrame as a csv

# %%
nyc_SA_arrests.to_csv(r'../data/clean/NYPD_Arrests_Data_Historic_CLEAN_SA.csv')
